# %% [markdown]
# # --- Day 11: Reactor ---

# %%
# --- Support Functions ---
# This section contains support functions used by the main code.
# %pip install tqdm

from tqdm.notebook import tqdm
import time

def read_input(file_path):
    with open(file_path, 'r') as file:
        return file.read().splitlines()
    
def traverse_tree(start: str, end: str, tree: dict) -> list[list]:
    paths=[]
    queue = [[start]]
    pbar = tqdm(desc="Tree Exploration", dynamic_ncols=True)
    idx = 0
    while queue:
        path = queue.pop()
        idx +=1    
        pbar.set_description(f"Visito: {idx}: {path[-1]} | Trovate: {len(paths)}")
        for b in tree.get(path[-1], []):
            p = path.copy()+[b]
            if b == end:
                paths.append(p)
                pbar.update(1)
                pbar.set_description(f"Trovate: {len(paths)}")
                break
            queue.append(p)
    pbar.close()
    return(paths)

def traverse_tree_dfs(start: str, end: str, tree: dict, max_paths: int | None = None) -> list[list]:
    """
    DFS con backtracking, evita cicli e non copia la path ad ogni figlio.
    Se max_paths è fornito interrompe dopo aver trovato quel numero di soluzioni.
    """
    paths: list[list] = []
    path: list[str] = [start]
    seen: set[str] = {start}

    pbar = tqdm(desc="Tree Exploration", dynamic_ncols=True)
    idx = 0
    def dfs(node: str) -> bool:
        global idx
        if node == end:
            if ('fft' in path) and ('dac' in path):
                # paths.append(path.copy())
                idx+=1
                pbar.set_description(f"Trovate: {idx}")
            return bool(max_paths and len(paths) >= max_paths)
        for child in tree.get(node, []):
            if child in seen:
                continue
            seen.add(child)
            path.append(child)
            stop = dfs(child)
            path.pop()
            seen.remove(child)
            if stop:
                return True
        return False

    dfs(start)
    pbar.close()
    return idx
# Out:
# Requirement already satisfied: tqdm in /workspaces/advent-of-code-2025/.venv/lib/python3.12/site-packages (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- Part ONE ---

input = read_input('input.txt')

start = 'you'
end = 'out'

# construct "tree" of parents and childs
childs = {}
parents = {}  # not necessary
for l in input:
    p, cs = l.split(':')
    cs = cs.strip().split(' ')
    childs[p] = cs
    for c in cs:
        pp = (parents.get(c, []))
        pp.append(p)
        parents[c] = pp
# print(f"{childs}")
# print(f"{parents}")


paths = traverse_tree(start, end, childs)

result = len(paths)

print("Part ONE:", result)
# Out:
# Tree Exploration:   0%|          | 0/1 [00:00<?, ?it/s]
# Part ONE: 782

# %%
# --- Part TWO ---
input = read_input('input.txt')

result = 0

start = 'svr'
end = 'out'

# construct "tree" of parents and childs
childs = {}
parents = {} # not necessary
for l in input:
    p, cs = l.split(':')
    cs = cs.strip().split(' ')
    childs[p] = cs
    for c in cs:
        pp = (parents.get(c, []))
        pp.append(p)
        parents[c] = pp

paths = traverse_tree_dfs(start, end, childs)
#s_f = len(traverse_tree_dfs(start, 'fft', childs))
#d_f = len(traverse_tree_dfs('dac', 'fft', childs))
#f_d = len(traverse_tree_dfs('fft', 'dac', childs))
#d_o = len(traverse_tree_dfs('dac', end, childs))
#f_o = len(traverse_tree_dfs('fft', end, childs))

#result = (s_d*d_f*f_o)+(s_f*f_d*d_o)

#result = len([p for p in paths if ('dac'in p) and ('fft' in p)])

print("Part TWO:", result)
# Out:
# Tree Exploration: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 21
#      18         pp.append(p)
#      19         parents[c] = pp
# ---> 21 paths = traverse_tree_dfs(start, end, childs)
#      22 #s_f = len(traverse_tree_dfs(start, 'fft', childs))
#      23 #d_f = len(traverse_tree_dfs('dac', 'fft', childs))
#      24 #f_d = len(traverse_tree_dfs('fft', 'dac', childs))
#    (...)     29
#      30 #result = len([p for p in paths if ('dac'in p) and ('fft' in p)])
#      32 print("Part TWO:", result)
#
# Cell In[17], line 62, in traverse_tree_dfs(start, end, tree, max_paths)
#      59             return True
#      60     return False
# ---> 62 dfs(start)
#      63 pbar.close()
#      64 return idx
#
# Cell In[17], line 55, in traverse_tree_dfs.<locals>.dfs(node)
#      53 seen.add(child)
#      54 path.append(child)
# ---> 55 stop = dfs(child)
#      56 path.pop()
#      57 seen.remove(child)
#
# Cell In[17], line 55, in traverse_tree_dfs.<locals>.dfs(node)
#      53 seen.add(child)
#      54 path.append(child)
# ---> 55 stop = dfs(child)
#      56 path.pop()
#      57 seen.remove(child)
#
#     [... skipping similar frames: traverse_tree_dfs.<locals>.dfs at line 55 (31 times)]
#
# Cell In[17], line 55, in traverse_tree_dfs.<locals>.dfs(node)
#      53 seen.add(child)
#      54 path.append(child)
# ---> 55 stop = dfs(child)
#      56 path.pop()
#      57 seen.remove(child)
#
# Cell In[17], line 49, in traverse_tree_dfs.<locals>.dfs(node)
#      47         idx+=1
#      48         pbar.set_description(f"Trovate: {idx}")
# ---> 49     return bool(max_paths and len(paths) >= max_paths)
#      50 for child in tree.get(node, []):
#      51     if child in seen:
#
# KeyboardInterrupt:

# %%
for i in tqdm(range(100), desc="Elaborazione"):
    time.sleep(0.05)  # Simula un'operazione
# Out:
# Elaborazione:   0%|          | 0/100 [00:00<?, ?it/s]
