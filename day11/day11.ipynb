# %% [markdown]
# # --- Day 11: Reactor ---

# %%
# --- Support Functions ---
# This section contains support functions used by the main code.

def read_input(file_path):
    with open(file_path, 'r') as file:
        return file.read().splitlines()
    
def traverse_tree(start: str, end: str, tree: dict) -> list[list]:
    paths=[]
    # seen = set()
    queue = [[start]]
    while queue:
        path = queue.pop()
        for b in tree.get(path[-1], []):
            p = path.copy()+[b]
            if b == end:
                paths.append(p)
                break
            # if b in seen:
            #     continue
            # seen.add(b)
            queue.append(p)
            # print(p)    
    return(paths)

# %%
# --- Part ONE ---

input = read_input('input.txt')

end = 'out'
start = 'you'


# construct "tree" of parents and childs
childs = {}
parents = {}
for l in input:
    p, cs = l.split(':')
    cs = cs.strip().split(' ')
    childs[p] = cs
    for c in cs:
        pp = (parents.get(c, []))
        pp.append(p)
        parents[c] = pp
# print(f"{childs}")
# print(f"{parents}")


paths = traverse_tree(start, end, childs)

result = len(paths)

print("Part ONE:", result)
# Out:
# {'lvy': ['oyl', 'fyu', 'wde', 'kxs'], 'ozc': ['ziu', 'zyw', 'omn', 'kzo'], 'mkn': ['emx'], 'uqb': ['ksk', 'qzd', 'dev'], 'ijk': ['ljo'], 'twp': ['out'], 'wgs': ['cyd', 'oou', 'aat'], 'xry': ['yec', 'isd', 'qhl', 'wsb'], 'iog': ['mnx', 'alc', 'txi'], 'ysm': ['xau', 'qki', 'jiy', 'bsq', 'qww', 'ncs', 'kdp', 'bns'], 'hwd': ['nhp', 'nnw', 'cpq', 'yxi'], 'cxm': ['igg', 'twj'], 'zpt': ['dac', 'qpd', 'ouf', 'dmk', 'vvw'], 'qve': ['blh', 'jts', 'eis', 'iyi', 'mze', 'cuw', 'uks', 'fwl'], 'epv': ['pau', 'ova'], 'qld': ['dev'], 'xir': ['iix', 'qve'], 'jkt': ['qve', 'you', 'iix'], 'cab': ['iix'], 'upc': ['qzc'], 'pau': ['xbq'], 'pkh': ['out'], 'chr': ['nrs'], 'tbt': ['umo', 'uqw', 'qld'], 'gxe': ['hzw', 'xfa', 'qah'], 'fzn': ['kzo', 'omn'], 'vtf': ['rgb', 'qlh'], 'kgt': ['uvw'], 'ebl': ['rit', 'nfd'], 'umo': ['qzd', 'ksk'], 'xlf': ['nrw', 'wbs'], 'kzo': ['tbj', 'xwp', 'uum', 'xva', 'sob', 'nzy', 'uax', 'mnk', 'ahn', 'dds', 'fot', 'wpd', 'auy', 'xlk', 'dlf', 'qkk', 'yoo', 'idv', 'ruu', 'udv'], 'pjs': ['izd', 'oyz', 'ock'], 'iyi': ['rzv'], 'rob': ['umq'], 'abs': ['eiz', 'qmi', 'coc'], 'lza': ['hhq'], 'cyo': ['kzo', 'omn', 'ziu'], 'cyd': ['fzz', 'pbd', 'hop'], 'fyu': ['dqy', 'teq'], 'mlz': ['scp'], 'zne': ['dqf', 'ixz', 'izb', 'cjz'], 'htl': ['chr', 'ffu', 'fki'], 'xpp': ['ljo'], 'dqf': ['qzd', 'dev'], 'khb': ['fiq', 'iaa'], 'ogp': ['uqw', 'qld'], 'qpm': ['she', 'qzx', 'dju'], 'zeh': ['csx', 'cwj'], 'bsq': ['ijj', 'xoj', 'zzo', 'cqt'], 'nto': ['qxt'], 'cpq': ['ysm', 'qmi', 'eiz'], 'lke': ['efe', 'cwj'], 'ueo': ['ovj', 'ixw', 'kwj'], 'brf': ['ygg', 'vvi'], 'rov
'cuw': ['qve'], 'uks': ['qve'], 'fwl': ['qve', 'you', 'iix'], 'pau': ['epv', 'bst', 'mzi'], 'ova': ['epv', 'bst', 'nrs'], 'iix': ['xir', 'jkt', 'cab', 'ctm', 'ndx', 'whh', 'vnh', 'omq', 'nla', 'ywd', 'yws', 'iaa', 'jbo', 'rxl', 'fiq'], 'qve': ['xir', 'jkt', 'myw', 'hru', 'whh', 'whr', 'vnh', 'ywd', 'hca', 'jbo', 'rxl', 'fiq', 'tdr'], 'you': ['jkt', 'nkc', 'ctm', 'myw', 'ndx', 'whr', 'vnh', 'bgc', 'psb', 'iaa', 'jbo', 'tdr'], 'qzc': ['upc'], 'xbq': ['pau', 'efe', 'cwj', 'ndu', 'ebr', 'xzx', 'arl', 'xdd', 'jlw', 'fvs', 'rsm', 'yoi', 'ctz'], 'nrs': ['chr', 'ffu'], 'umo': ['tbt', 'rjx', 'qua', 'yqy'], 'uqw': ['tbt', 'ogp', 'yqy'], 'qld': ['tbt', 'ogp', 'qua'], 'hzw': ['gxe', 'tph', 'jux'], 'xfa': ['gxe', 'tph', 'jux'], 'qah': ['gxe', 'tph', 'jux'], 'rgb': ['vtf', 'hke', 'dsf'], 'qlh': ['vtf', 'dse', 'hke', 'dsf'], 'uvw': ['kgt', 'efe', 'cwj', 'ndu', 'csx', 'sad', 'ebr', 'xzx', 'ova', 'fvs', 'hov', 'rsm', 'yoi'], 'rit': ['ebl', 'gkq'], 'nfd': ['ebl', 'zfp'], 'nrw': ['xlf', 'utp', 'ptg'], 'wbs': ['xlf', 'ptg', 'tpp'], 'tbj': ['kzo', 'zyw', 'ziu', 'omn'], 'xwp': ['kzo', 'zyw', 'ziu', 'omn'], 'uum': ['kzo', 'zyw', 'ziu', 'omn'], 'xva': ['kzo', 'zyw', 'omn'], 'sob': ['kzo', 'zyw', 'ziu', 'omn'], 'nzy': ['kzo', 'zyw', 'ziu', 'omn'], 'uax': ['kzo', 'zyw', 'ziu', 'omn'], 'mnk': ['kzo', 'zyw', 'ziu', 'omn'], 'ahn': ['kzo', 'zyw', 'omn'], 'dds': ['kzo', 'zyw', 'ziu', 'omn'], 'fot': ['kzo', 'zyw', 'ziu', 'omn'], 'wpd': ['kzo', 'zyw', 'ziu', 'omn'], 'auy': ['kzo', 'zyw', 'ziu'], 'xlk': ['kzo', 'zyw', 'ziu', 'omn'], 'dlf': ['kzo', 'ziu', 'omn'], 'qkk': ['kzo', 'zyw', 'ziu', 'omn'], 'yoo': ['kzo', 'zyw', 'ziu', 'omn'], 'idv': ['kzo', 'zyw', 'omn'], 'ruu': ['kzo', 'zyw', 'ziu', 'omn'], 'udv': ['kzo', 'zyw', 'ziu', 'omn'], 'izd': ['pjs', 'phq'], 'oyz': ['pjs', 'lvx', 'phq'], 'ock': ['pjs', 'lvx'], 'rzv': ['iyi', 'xdy', 'fwl', 'blh'], 'umq': ['rob', 'iof', 'pul', 'czy'], 'eiz': ['abs', 'cpq', 'qhl', 'nnw', 'nbe', 'mat', 'ydy', 'bdo', 'isd', 'yec', 'nhp', 'hib'], 'qmi': ['abs', 'cpq', 'qhl', 'nnw', 'tve', 'bgb', 'isd', 'yec', 'nhp', 'rdz', 'ois'], 'coc': ['abs', 'qhl', 'edi', ...
# Part ONE: 782

# %%
# --- Part TWO ---
input = read_input('test1.txt')

result = 0


print("Part TWO:", result)
